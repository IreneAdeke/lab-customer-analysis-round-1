# %%
import pandas as pd

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/ironhack-labs/lab-customer-analysis-round-1/master/files_for_lab/csv_files/file1.csv")

# %%
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/ironhack-labs/lab-customer-analysis-round-1/master/files_for_lab/csv_files/file2.csv")

# %%
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3 = pd.read_csv("https://raw.githubusercontent.com/ironhack-labs/lab-customer-analysis-round-1/master/files_for_lab/csv_files/file3.csv")

# %%
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
# The shape of the dataframes
df1.shape
# Out:
# (4008, 11)

# %%
df2.shape
# Out:
# (996, 11)

# %%
df3.shape
# Out:
# (7070, 11)

# %%
df1.head
# Out:
# <bound method NDFrame.head of      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
# Standardise column names 
df1.rename(columns = {'GENDER': 'Gender', 'ST': 'State'})
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df2.rename(columns = {'GENDER': 'Gender', 'ST': 'State'})
# Out:
#     Customer       State Gender Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
#Concatenating the three data frames: 
combined_dataframes = pd.concat([df1,df2,df3])

# %%
combined_dataframes
# Out:
#      Customer          ST GENDER Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316         NaN    NaN             23405.98798  71941.0
# 7066  PK87824         NaN    NaN             3096.511217  21604.0
# 7067  TD14365         NaN    NaN             8163.890428      0.0
# 7068  UP19263         NaN    NaN             7524.442436  21941.0
# 7069  Y167826         NaN    NaN             2611.836866      0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#To find out which columns are numeric: 
from pandas.api.types import is_numeric_dtype

# %%
combined_dataframes.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# State                         object
# Gender                        object
# dtype: object

# %%
#Numerical columns are: 
#Income, Number of open complaints, Monthly premium Auto

# %%
#Categorical Columns are: 
#Vehicle class, Policy Type, Gender, Education

# %%
#Deleting 'Education'
del combined_dataframes['Education']

# %%
combined_dataframes
# Out:
#      Customer          ST GENDER Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316         NaN    NaN             23405.98798  71941.0
# 7066  PK87824         NaN    NaN             3096.511217  21604.0
# 7067  TD14365         NaN    NaN             8163.890428      0.0
# 7068  UP19263         NaN    NaN             7524.442436  21941.0
# 7069  Y167826         NaN    NaN             2611.836866      0.0
#
#       Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                   1000.0                    1/0/00   Personal Auto
# ...

# %%
#Deleting 'Number of Open Complaints'
del combined_dataframes['Number of Open Complaints']

# %%
combined_dataframes
# Out:
#      Customer          ST GENDER Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316         NaN    NaN             23405.98798  71941.0
# 7066  PK87824         NaN    NaN             3096.511217  21604.0
# 7067  TD14365         NaN    NaN             8163.890428      0.0
# 7068  UP19263         NaN    NaN             7524.442436  21941.0
# 7069  Y167826         NaN    NaN             2611.836866      0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
combined_dataframes['Customer Lifetime Value']
# Out:
#       Customer Lifetime Value  Customer Lifetime Value  \
# 0                         NaN               323912.47%
# 1                  697953.59%               462680.11%
# 2                 1288743.17%               899704.02%
# 3                  764586.18%              2580706.30%
# 4                  536307.65%               380812.21%
# ...                       ...                      ...
# 7065                      NaN                      NaN
# 7066                      NaN                      NaN
# 7067                      NaN                      NaN
# 7068                      NaN                      NaN
# 7069                      NaN                      NaN
#
#       Customer Lifetime Value
# 0                 3479.137523
# 1                 2502.637401
# 2                 3265.156348
# 3                 4455.843406
# 4                 7704.958480
# ...                       ...
# 7065             23405.987980
# 7066              3096.511217
# ...

# %%
#Multiplying values of Customer Lifetime Value by 100
combined_dataframes[['Customer Lifetime Value']] * 100
# Out:
#                                 Customer Lifetime Value
# 0                                                   NaN
# 1     697953.59%697953.59%697953.59%697953.59%697953...
# 2     1288743.17%1288743.17%1288743.17%1288743.17%12...
# 3     764586.18%764586.18%764586.18%764586.18%764586...
# 4     536307.65%536307.65%536307.65%536307.65%536307...
# ...                                                 ...
# 7065                                        2340598.798
# 7066                                        309651.1217
# 7067                                        816389.0428
# 7068                                        752444.2436
# 7069                                        261183.6866
#
# [12074 rows x 1 columns]

# %%
#datatype changed to numerical
combined_dataframes.dtypes
# Out:
# Customer                    object
# ST                          object
# GENDER                      object
# Customer Lifetime Value     object
# Income                     float64
# Monthly Premium Auto       float64
# Policy Type                 object
# Vehicle Class               object
# Total Claim Amount         float64
# State                       object
# Gender                      object
# dtype: object

# %%
#Checking for duplicate rows
duplicate_rows = combined_dataframes.duplicated()

# %%
#There are no duplicate rows
print(duplicate_rows)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067    False
# 7068    False
# 7069    False
# Length: 12074, dtype: bool

# %%
#Filtering out the data for customers who have an income of 0 or less.
combined_dataframes['Income'] <= 0
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067     True
# 7068    False
# 7069     True
# Name: Income, Length: 12074, dtype: bool

# %%
combined_dataframes[low_income]
# Out:
#      Customer          ST GENDER Customer Lifetime Value  Income  \
# 0     RB50392  Washington    NaN                     NaN     0.0
# 1     QZ44356     Arizona      F              697953.59%     0.0
# 3     WW63253  California      M              764586.18%     0.0
# 7     CF85061     Arizona      M              721610.03%     0.0
# 10    SX51350  California      M              473899.20%     0.0
# ...       ...         ...    ...                     ...     ...
# 7059  WZ45103         NaN    NaN             5678.050167     0.0
# 7061  RX91025         NaN    NaN               19872.262     0.0
# 7062  AC13887         NaN    NaN             4628.995325     0.0
# 7067  TD14365         NaN    NaN             8163.890428     0.0
# 7069  Y167826         NaN    NaN             2611.836866     0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
